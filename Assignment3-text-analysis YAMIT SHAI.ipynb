# %% [markdown]
# # Assignment 3 - Text Analysis
# An explanation this assignment could be found in the .pdf explanation document

# %% [markdown]
# ## Materials to review for this assignment
# <h4>From Moodle:</h4>
# <h5><u>Review the notebooks regarding the following python topics</u>:</h5>
# <div class="alert alert-info">
# &#x2714; <b>Working with strings</b> (tutorial notebook)<br/>
# &#x2714; <b>Text Analysis</b> (tutorial notebook)<br/>
# &#x2714; <b>Hebrew text analysis tools (tokenizer, wordnet)</b> (moodle example)<br/>
# &#x2714; <b>(brief review) All previous notebooks</b><br/>
# </div>
# <h5><u>Review the presentations regarding the following topics</u>:</h5>
# <div class="alert alert-info">
# &#x2714; <b>Text Analysis</b> (lecture presentation)<br/>
# &#x2714; <b>(brief review) All other presentations</b><br/>
# </div>

# %% [markdown]
# ## Personal Details:

# %% [markdown]
# ## Preceding Step - import modules (packages)
# This step is necessary in order to use external modules (packages). <br/>

# %%
# --------------------------------------
import pandas as pd
import numpy as np
# --------------------------------------


# --------------------------------------
# ------------- visualizations:
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# --------------------------------------


# ---------------------------------------
import sklearn
from sklearn import preprocessing, metrics, pipeline, model_selection, feature_extraction 
from sklearn import naive_bayes, linear_model, svm, neural_network, neighbors, tree
from sklearn import decomposition, cluster

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV 
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error, r2_score, silhouette_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import Perceptron, SGDClassifier
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
# ---------------------------------------


# ----------------- output and visualizations: 
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=ConvergenceWarning)
# show several prints in one cell. This will allow us to condence every trick in one cell.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# ---------------------------------------

# %%
# --------------------------------------
# --------- Text analysis and Hebrew text analysis imports:
# vectorizers:
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# regular expressions:
import re
# --------------------------------------

# %%
# Details Student 1:
206776486
# Details Student 2:
206842585
# Out:
# 206776486
# 206842585

# %% [markdown]
# #### (optional) Only if you didn't install Wordnet (for Hebrew) use:

# %%
# word net installation:

# unmark if you want to use and need to install
# !pip install wn
# !python -m wn download omw-he:1.4
# Out:
# Requirement already satisfied: wn in c:\users\kroi4\anaconda3\lib\site-packages (0.9.4)
# Requirement already satisfied: requests in c:\users\kroi4\anaconda3\lib\site-packages (from wn) (2.22.0)
# Requirement already satisfied: tomli in c:\users\kroi4\anaconda3\lib\site-packages (from wn) (2.0.1)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\kroi4\anaconda3\lib\site-packages (from wn) (4.7.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kroi4\anaconda3\lib\site-packages (from requests->wn) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kroi4\anaconda3\lib\site-packages (from requests->wn) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kroi4\anaconda3\lib\site-packages (from requests->wn) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kroi4\anaconda3\lib\site-packages (from requests->wn) (2.8)
# Cached file found: C:\Users\kroi4\.wn_data\downloads\7ecf10e89326bc0ac26ad94b40fe60a7b6ac3302
#
# Checking C:\Users\kroi4\AppData\Local\Temp\tmp0g5ubbol\omw-he\omw-he.xml
# Skipping omw-he:1.4 (Hebrew Wordnet); already added

# %%
# word net import:

# unmark if you want to use:
import wn

# %% [markdown]
# ### (optional) Hebrew text analysis - hebrew_tokenizer (Tokenizer for Hebrew)
# Note: the hebrew_tokenizer is not a must

# %% [markdown]
# #### (optional) Only if you didn't install hebrew_tokenizer use:

# %%
# Hebrew tokenizer installation:

# unmark if you want to use and need to install:
# !pip install hebrew_tokenizer

# %%
# Hebrew tokenizer import:

# unmark if you want to use:
import hebrew_tokenizer as ht

# %% [markdown]
# ### Reading input files
# Reading input files for train annotated corpus (raw text data) corpus and for the test corpus

# %%
train_filename = 'annotated_corpus_for_train.csv'
test_filename  = 'corpus_for_test.csv'
df_train = pd.read_csv(train_filename, index_col=None, encoding='utf-8')
df_test  = pd.read_csv(test_filename, index_col=None, encoding='utf-8')

# %%
df_train.head(8)
df_train.shape
# Out:
#                                                story gender
# 0  כשחבר הזמין אותי לחול, לא באמת חשבתי שזה יקרה,...      m
# 1  לפני שהתגייסתי לצבא עשיתי כל מני מיונים ליחידו...      m
# 2  מאז שהתחילו הלימודים חלומו של כל סטודנט זה הפנ...      f
# 3  כשהייתי ילד, מטוסים היה הדבר שהכי ריתק אותי. ב...      m
# 4  ‏הייתי מדריכה בכפר נוער ומתאם הכפר היינו צריכי...      f
# 5  לפני כ3 חודשים טסתי לרומא למשך שבוע. טסתי במטו...      f
# 6  אני כבר שנתיים נשוי והשנה אני ואישתי סוף סוף י...      m
# 7  השנה התחלנו שיפוץ בדירה שלנו בתל אביב. הדירה ה...      f
# (753, 2)

# %%
df_test.head(3)
df_test.shape
# Out:
#    test_example_id                                              story
# 0                0  כל קיץ אני והמשפחה נוסעים לארצות הברית לוס אנג...
# 1                1  הגעתי לשירות המדינה אחרי שנתיים כפעיל בתנועת "...
# 2                2  אחת האהבות הגדולות שלי אלו הכלבים שלי ושל אישת...
# (323, 2)

# %% [markdown]
# ### Your implementation:
# Write your code solution in the following code-cells

# %% [markdown]
# # Preprocessing:

# %%
#(Data pre-processing)
def my_tokenizer(hebrew_text):
    token = ht.tokenize(hebrew_text)
    tokens_list = list(filter(lambda x: (x[0] == 'HEBREW'),token))
    tokens_list = [tuple[1] for tuple in tokens_list]
    tokens_list
    return tokens_list

# %%
# convert the target from categorial values to binary values
df_train['gender'] = np.where(df_train['gender'] == 'm',1,0)

# %%
# split the training data set to feature vectors and target label
X_train = df_train['story']
y_train = df_train['gender']

# %% [markdown]
# # Training + Cross validation:

# %%
# finding best params using gridsearch(cross validation)


#SVM
SGDClassifier_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=my_tokenizer)),
    ('normalize', preprocessing.Normalizer(norm='l2')),
    ('clf', SGDClassifier(max_iter=1000, random_state=42))
])


#Naive bayes
NB_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=my_tokenizer)),
    ('normalize', preprocessing.Normalizer(norm='l2')),
    ('clf', MultinomialNB())
])


#LineaerSVC
svc_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=my_tokenizer, ngram_range=(1, 1))),
    ('normalize', preprocessing.Normalizer(norm='l2')),
    ('classifier', LinearSVC())
])

perceptron_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(tokenizer=my_tokenizer ,ngram_range=(1,1))),
    ('normalize', preprocessing.Normalizer(norm='l2')),
    ('classifier', Perceptron())
])

best_model = None
best_f1_score = 0

# Define the parameter grids for each pipeline
SGDClassifier_param_grid = {
    'tfidf__max_df': [0.5, 0.75, 1.0],
    'clf__alpha': [0.0001, 0.001, 0.01, 0.1],
    'clf__penalty': ['l1', 'l2', 'elasticnet']
    }
   

NB_param_grid = {
    'tfidf__max_df': [0.5, 0.75, 1.0],
    'clf__alpha': [0.0001, 0.001, 0.01, 0.1]
}


svc_param_grid = {
    'tfidf__max_df': [0.5, 0.75, 1.0],
    'classifier__C': [0.1, 1, 10]
   
}

perceptron_param_grid = {
    'tfidf__max_df': [0.5, 0.75, 1.0],
    'classifier__alpha' : [0.0001, 0.001, 0.01],
    'classifier__penalty': ['l1', 'l2', 'elasticnet', None],
    
}

# Define the list of pipelines to evaluate
pipelines = [
    ('SGDClassifier', SGDClassifier_pipeline, SGDClassifier_param_grid),
    ('Naive Bayes', NB_pipeline, NB_param_grid),
    ('Linear SVC', svc_pipeline, svc_param_grid),
    ('Perceptron', perceptron_pipeline, perceptron_param_grid)
]

# Loop over the pipelines and perform grid search with cross-validation
f1_scores = {}

for name, pipeline, param_grid in pipelines:
    print(f"Evaluating {name}...")
    grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='f1_macro')
    grid_search.fit(X_train, y_train)
    scores = cross_val_score(grid_search.best_estimator_,X_train, y_train, cv=10, scoring='f1_macro')
    avg_f1_score = scores.mean()
    f1_scores[name] = avg_f1_score
    print(f"Average F1 score for {name}: {avg_f1_score}")
    print(f"Best hyperparameters: {grid_search.best_params_}")

best_model = max(f1_scores, key=f1_scores.get)
best_f1_score = f1_scores[best_model]

print(f"The best model is {best_model} with an average F1 score of {best_f1_score}.")
# Out:
# Evaluating SGDClassifier...
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop_wor...
#                                                       power_t=0.5,
#                                                       random_state=42,
#                                                       shuffle=True, tol=0.001,
#                                                       validation_fraction=0.1,
#                                                       verbose=0,
#                                                       warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'clf__alpha': [0.0001, 0.001, 0.01, 0.1],
#                          'clf__penalty': ['l1', 'l2', 'elasticnet'],
#                          'tfidf__max_df': [0.5, 0.75, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_macro', verbose=0)
# Average F1 score for SGDClassifier: 0.7038614642501508
# Best hyperparameters: {'clf__alpha': 0.0001, 'clf__penalty': 'l1', 'tfidf__max_df': 0.75}
# Evaluating Naive Bayes...
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop_wor...
#                                                         use_idf=True,
#                                                         vocabulary=None)),
#                                        ('normalize',
#                                         Normalizer(copy=True, norm='l2')),
#                                        ('clf',
#                                         MultinomialNB(alpha=1.0,
#                                                       class_prior=None,
#                                                       fit_prior=True))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'clf__alpha': [0.0001, 0.001, 0.01, 0.1],
#                          'tfidf__max_df': [0.5, 0.75, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_macro', verbose=0)
# Average F1 score for Naive Bayes: 0.49734890516831054
# Best hyperparameters: {'clf__alpha': 0.01, 'tfidf__max_df': 0.5}
# Evaluating Linear SVC...
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop_wor...
#                                                   dual=True, fit_intercept=True,
#                                                   intercept_scaling=1,
#                                                   loss='squared_hinge',
#                                                   max_iter=1000,
#                                                   multi_class='ovr',
#                                                   penalty='l2',
#                                                   random_state=None, tol=0.0001,
#                                                   verbose=0))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'classifier__C': [0.1, 1, 10],
#                          'tfidf__max_df': [0.5, 0.75, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_macro', verbose=0)
# Average F1 score for Linear SVC: 0.6329432546620047
# Best hyperparameters: {'classifier__C': 10, 'tfidf__max_df': 1.0}
# Evaluating Perceptron...
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop_wor...
#                                                    random_state=0, shuffle=True,
#                                                    tol=0.001,
#                                                    validation_fraction=0.1,
#                                                    verbose=0,
#                                                    warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'classifier__alpha': [0.0001, 0.001, 0.01],
#                          'classifier__penalty': ['l1', 'l2', 'elasticnet',
#                                                  None],
#                          'tfidf__max_df': [0.5, 0.75, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_macro', verbose=0)
# Average F1 score for Perceptron: 0.6700254560137411
# Best hyperparameters: {'classifier__alpha': 0.0001, 'classifier__penalty': None, 'tfidf__max_df': 0.75}
# The best model is SGDClassifier with an average F1 score of 0.7038614642501508.

# %% [markdown]
# # try to maxmize the best models

# %%
best_model = Pipeline(
    [
        ('tfidf', TfidfVectorizer(tokenizer=my_tokenizer,
        max_df=1.0, ngram_range=(1, 1)),),
        ('normalize', preprocessing.Normalizer(norm='l2')),
        ('clf', Perceptron(alpha= 0.0001, penalty='elasticnet' ))
    ])

best_model.fit(X_train, y_train)
f1_scores = cross_val_score(
    best_model, X_train, y_train, cv=10, scoring='f1_macro')
avg_f1_score = np.mean(f1_scores)
print("Average F1 score:", avg_f1_score)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='...
#                                  tokenizer=<function my_tokenizer at 0x00000214CA4C31E0>,
#                                  use_idf=True, vocabulary=None)),
#                 ('normalize', Normalizer(copy=True, norm='l2')),
#                 ('clf',
#                  Perceptron(alpha=0.0001, class_weight=None,
#                             early_stopping=False, eta0=1.0, fit_intercept=True,
#                             max_iter=1000, n_iter_no_change=5, n_jobs=None,
#                             penalty='elasticnet', random_state=0, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False))],
#          verbose=False)
# Average F1 score: 0.6184679500071688

# %%
best_model = Pipeline(
    [
        ('tfidf', TfidfVectorizer(tokenizer=my_tokenizer,analyzer='word',
        max_df=0.73, ngram_range=(1, 1))),
        ('normalize', preprocessing.Normalizer(norm='l2')),
        ('clf', SGDClassifier(max_iter=22,random_state=42, alpha=0.0001,penalty='l1', loss='hinge', learning_rate='optimal', eta0=1, validation_fraction=0.1, n_iter_no_change=6,))
    ])

best_model.fit(X_train, y_train)
f1_scores = cross_val_score(
    best_model, X_train, y_train, cv=10, scoring='f1_macro')
avg_f1_score = np.mean(f1_scores)
print("Average F1 score:", avg_f1_score)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=0.73, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern=...
#                 ('clf',
#                  SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#                                early_stopping=False, epsilon=0.1, eta0=1,
#                                fit_intercept=True, l1_ratio=0.15,
#                                learning_rate='optimal', loss='hinge',
#                                max_iter=22, n_iter_no_change=6, n_jobs=None,
#                                penalty='l1', power_t=0.5, random_state=42,
#                                shuffle=True, tol=0.001, validation_fraction=0.1,
#                                verbose=0, warm_start=False))],
#          verbose=False)
# Average F1 score: 0.7140506024465758

# %%
# predict the y_train

# %%
# use the best estimator model for learning
y_pred = best_model.predict(df_test["story"])
y_pred = np.where(y_pred == 1, 'm', 'f')

pd.DataFrame({'id_test': df_test["test_example_id"], 'y_pred': y_pred}).head(5)
pd.DataFrame({'id_test': df_test["test_example_id"], 'y_pred': y_pred}).tail(5)
# Out:
#    id_test y_pred
# 0        0      m
# 1        1      m
# 2        2      m
# 3        3      m
# 4        4      m
#      id_test y_pred
# 318      318      m
# 319      319      m
# 320      320      m
# 321      321      m
# 322      322      m

# %%
# create dataframe

# %%
# create dataframe with the test results
df_predicted = pd.DataFrame(
    {'test_example_id': df_test['test_example_id'], 'predicted_category': y_pred})
df_predicted
# Out:
#      test_example_id predicted_category
# 0                  0                  m
# 1                  1                  m
# 2                  2                  m
# 3                  3                  m
# 4                  4                  m
# 5                  5                  m
# 6                  6                  m
# 7                  7                  f
# 8                  8                  m
# 9                  9                  m
# 10                10                  f
# 11                11                  m
# 12                12                  m
# 13                13                  m
# 14                14                  f
# 15                15                  m
# 16                16                  m
# 17                17                  m
# 18                18                  m
# 19                19                  m
# 20                20                  f
# 21                21                  m
# 22                22                  m
# 23                23                  m
# 24                24                  m
# 25                25                  m
# 26                26                  m
# 27                27                  m
# 28                28                  m
# 29                29                  m
# ..               ...                ...
# 293              293                  m
# 294              294                  m
# 295              295                  m
# 296              296                  m
# 297              297                  f
# 298              298                  f
# 299              299                  m
# 300              300                  m
# 301              301                  m
# 302              302                  m
# 303              303                  m
# 304              304                  m
# 305              305                  m
# 306              306                  m
# 307              307                  m
# 308              308                  m
# 309              309                  m
# 310              310                  f
# 311              311                  m
# 312              312                  m
# 313              313                  m
# 314              314                  f
# 315              315                  m
# 316              316                  m
# 317              317                  m
# 318              318                  m
# 319              319                  m
# 320              320                  m
# 321              321                  m
# 322              322                  m
#
# [323 rows x 2 columns]

# %% [markdown]
# ### Save output to csv (optional)
# After you're done save your output to the 'classification_results.csv' csv file.<br/>
# We assume that the dataframe with your results contain the following columns:
# * column 1 (left column): 'test_example_id'  - the same id associated to each of the test stories to be predicted.
# * column 2 (right column): 'predicted_category' - the predicted gender value for each of the associated story.
#
# Assuming your predicted values are in the `df_predicted` dataframe, you should save you're results as following:

# %%
df_predicted.to_csv('classification_results.csv',index=False)
